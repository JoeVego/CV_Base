# %%
import pandas as pd
from selenium import webdriver

from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Firefox()

# %%
url = "https://www.drom.ru/catalog/~search/?wheel=0&fuel_type_short%5B0%5D=0&page=4"

# %%
driver.get(url)

# %%
links = driver.find_elements(By.XPATH, '//a[@class="b-link"]')

# %%
list_links = []

for link_elem in links:
#     print(link_elem.get_attribute("href").count('/'))
    
    if link_elem.get_attribute("href").count('/') > 6 :
        list_links.append(link_elem.get_attribute("href"))
    

print(len(list_links))
# Out:
# 132

# %%
from selenium.common.exceptions import NoSuchElementException

list_capacity = []
list_power = []
list_name = []
list_errors = []
list_start_years = []

for link in list_links:
    try:
        driver.get(link)
    
        capacity = driver.find_element(By.XPATH, '//div[contains(text(), "Ёмкость")]/../*[2]')
        print(capacity.text)
        list_capacity.append(capacity.text)
    
        power = driver.find_element(By.XPATH, '//div[contains(text(), "Мощность")]/../*[2]')
        print(power.text)
        list_power.append(power.text)
    
        name = driver.find_element(By.XPATH, '//h1[contains(@class, "b-title b-title_type_h1")]')
        print(name.text[:-54])
        list_name.append(name.text[:-54])
        
        year = driver.find_element(By.XPATH, '//td[text()= "Период выпуска"]/../*[2]')
        print(year.text[-4:])
        list_start_years.append(year.text[-4:])
        
#         //td[text()= 'Период выпуска']/../*[2]
        
    except NoSuchElementException:
        name = driver.find_element(By.XPATH, '//h1[contains(@class, "b-title b-title_type_h1")]')
        list_errors.append(name.text)
        continue
    
pd1 = pd.Series(list_capacity)
pd2 = pd.Series(list_power)
pd3 = pd.Series(list_name)  
pd5 = pd.Series(list_start_years)

print(pd1)
print(pd2)
print(pd3)
print(pd5)
# Out:
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron e-tron 55 quattr
# 21 -
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron e-tron 50 qu
# 2022
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron e-tron 50 quattro adv
# 2021
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron e-tron 50 quattr
# 20 -
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e-tron Adv
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e-tron D
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e-tron
# 2022
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron 71 kWh 50 quattro e
# 2022
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron 71 kWh 50 quattro e-tron Adv
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e-tron Adv
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e-tron Premium
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron 95 kWh 55 quattro e-tron Pre
# 2022
# 93,0 кВт*ч
# 500 кВт
# Audi e-tron GT 93 kWh S e-tron GT
# 24 -
# 93,4 кВт*ч
# 390 кВт
# Audi e-tron GT e-tron GT
# 23 -
# 93,4 кВт*ч
# 390 кВт
# Audi e-tron GT e-tron GT qu
# 2023
# 93,0 кВт*ч
# 350 кВт
# Audi e-tron GT 93 kWh e-tron GT qu
# 2024
# 95,0 кВт*ч
# 370 кВт
# Audi e-tron S
# 22 -
# 95,0 кВт*ч
# 370 кВт
# Audi e-tron S 95 kWh quattro e-t
# 2022
# 95,0 кВт*ч
# 370 кВт
# Audi e-tron S 95 kWh quattro e-t
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback e-tron 55 quattr
# 21 -
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron Sportback e-tron 50 quattr
# 21 -
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback e-tron 55 quattro 1st
# 20 -
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e-tron Ad
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e-tron
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e-tron D
# 2022
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron Sportback 71 kWh 50 quattro e
# 2022
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron Sportback 71 kWh 50 quattro e-tron Adv
# 2022
# 71,0 кВт*ч
# 230 кВт
# Audi e-tron Sportback 71 kWh 50 quattro e-tron S
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e-tron Adv
# 2022
# 95,0 кВт*ч
# 300 кВт
# Audi e-tron Sportback 95 kWh 55 quattro e-tron S
# 2022
# 95,0 кВт*ч
# 370 кВт
# Audi e-tron Sportback S
# 22 -
# 95,0 кВт*ч
# 370 кВт
# Audi e-tron Sportback S 95 kWh quattro e-t
# 2022
# 95,0 кВт*ч
# 370 кВт
# Audi e-tron Sportback S 95 kWh quattro e-t
# 2022
# 95,0 кВт*ч
# 360 кВт
# Audi SQ6 e-tro
# 24 -
# 106,0 кВт*ч
# 370 кВт
# Audi SQ8 e-tron 106 kWh quattr
# 22 -
# 106,0 кВт*ч
# 370 кВт
# Audi SQ8 Sportback e-tron 106 kWh quattr
# 22 -
# 90,4 кВт*ч
# 230 кВт
# Avatr 11 90.38 kWh Long Battery Life
# 23 -
# 116,8 кВт*ч
# 230 кВт
# Avatr 11 116.8 kWh Super Long Battery Life
# 23 -
# 116,8 кВт*ч
# 230 кВт
# Avatr 11 116.8 kWh Super Long Battery Life
# 23 -
# 90,4 кВт*ч
# 425 кВт
# Avatr 11 90.38 kWh AWD Long Battery Life
# 22 -
# 90,4 кВт*ч
# 425 кВт
# Avatr 11 90.38 kWh AWD Long Battery Life
# 22 -
# 90,4 кВт*ч
# 425 кВт
# Avatr 11 90.38 kWh AWD Long Battery Life Luxury
# 22 -
# 90,4 кВт*ч
# 425 кВт
# Avatr 11 90.38 kWh AWD Long Battery Life Luxury
# 22 -
# 116,8 кВт*ч
# 425 кВт
# Avatr 11 116.8 kWh AWD Super Long Battery Life Luxury
# 22 -
# 116,8 кВт*ч
# 425 кВт
# Avatr 11 116.8 kWh AWD Super Long Battery Life Luxury
# 22 -
# 116,8 кВт*ч
# 425 кВт
# Avatr 11 116.8 kWh AWD 011 MMW Joint Limited
# 22 -
# 94,5 кВт*ч
# 230 кВт
# Avatr 12 94.5 kWh 70
# 23 -
# 94,5 кВт*ч
# 425 кВт
# Avatr 12 94.5 kWh AWD 650 Per
# 23 -
# 94,5 кВт*ч
# 425 кВт
# Avatr 12 94.5 kWh AW
# 23 -
# 61,8 кВт*ч
# 160 кВт
# BAIC BJEV EX5 61.8 k
# 19 -
# 61,8 кВт*ч
# 160 кВт
# BAIC BJEV EX5 61.8 k
# 19 -
# 61,8 кВт*ч
# 160 кВт
# BAIC BJEV EX5 61.8
# 19 -
# 61,8 кВт*ч
# 160 кВт
# BAIC BJEV EX5 61.8 kW
# 19 -
# 50,0 кВт*ч
# 120 кВт
# BAIC EU5 50 kW
# 22 -
# 50,0 кВт*ч
# 120 кВт
# BAIC EU5 50 kW
# 22 -
# 50,0 кВт*ч
# 160 кВт
# BAIC EU5 50 kWh High-Powe
# 22 -
# 50,8 кВт*ч
# 160 кВт
# BAIC EU5 50.8 kWh R5
# 20 -
# 50,8 кВт*ч
# 160 кВт
# BAIC EU5 50.8 kWh R5
# 20 -
# 60,0 кВт*ч
# 160 кВт
# BAIC EU5 60 kWh R
# 20 -
# 60,0 кВт*ч
# 160 кВт
# BAIC EU5 60 kWh R60
# 20 -
# 50,0 кВт*ч
# 120 кВт
# BAIC EU5 50 kWh Special Ed
# 2022
# 44,0 кВт*ч
# 120 кВт
# BAIC EU5 44 kWh Special
# 21 -
# 50,8 кВт*ч
# 160 кВт
# BAIC EU5 50.8 kWh Special Ed
# 2021
# 50,8 кВт*ч
# 160 кВт
# BAIC EU5 50.8 kWh R5
# 19 -
# 50,8 кВт*ч
# 160 кВт
# BAIC EU5 50.8 kWh R5
# 19 -
# 60,0 кВт*ч
# 160 кВт
# BAIC EU5 60 kWh R
# 19 -
# 60,0 кВт*ч
# 160 кВт
# BAIC EU5 60 kWh R60
# 19 -
# 53,6 кВт*ч
# 160 кВт
# BAIC EU5 53.6 kWh R500
# 2019
# 53,6 кВт*ч
# 160 кВт
# BAIC EU5 53.6 kWh R500
# 2019
# 60,2 кВт*ч
# 160 кВт
# BAIC EU5 60.2 kWh R550
# 2022
# 60,2 кВт*ч
# 160 кВт
# BAIC EU5 60.2 kWh R550 C
# 2022
# 49,6 кВт*ч
# 120 кВт
# BAIC EU5 Plus 49.6 kWh Premium Travel
# 23 -
# 49,6 кВт*ч
# 120 кВт
# BAIC EU5 Plus 49.6 kWh Honor Travel
# 23 -
# 49,6 кВт*ч
# 120 кВт
# BAIC EU5 Plus 49.6 kWh R500
# 21 -
# 49,6 кВт*ч
# 120 кВт
# BAIC EU5 Plus 49.6 kWh R5
# 21 -
# 60,7 кВт*ч
# 120 кВт
# BAIC EU5 Plus 60.7 kWh R600
# 21 -
# 60,7 кВт*ч
# 120 кВт
# BAIC EU5 Plus 60.7 kWh R6
# 21 -
# 60,7 кВт*ч
# 160 кВт
# BAIC EU7 60.7 k
# 21 -
# 60,7 кВт*ч
# 160 кВт
# BAIC EU7 60.7 k
# 21 -
# 60,7 кВт*ч
# 160 кВт
# BAIC EU7 60.7
# 21 -
# 60,2 кВт*ч
# 160 кВт
# BAIC EU7 60.2 kWh
# 2021
# 60,2 кВт*ч
# 160 кВт
# BAIC EU7 60.2 kWh
# 2021
# 60,2 кВт*ч
# 160 кВт
# BAIC EU7 60.2 kWh
# 2021
# 67,0 кВт*ч
# 210 кВт
# BMW i4
# 22 -
# 67,0 кВт*ч
# 210 кВт
# BMW i4 eDrive35
# 22 -
# 80,7 кВт*ч
# 250 кВт
# BMW i4
# 21 -
# 80,7 кВт*ч
# 250 кВт
# BMW i4 eDrive40
# 21 -
# 80,7 кВт*ч
# 400 кВт
# BM
# 21 -
# 83,9 кВт*ч
# 250 кВт
# BMW i4 eDrive40
# 22 -
# 83,9 кВт*ч
# 250 кВт
# BMW i4 eDr
# 2022
# 83,9 кВт*ч
# 400 кВт
# BM
# 22 -
# 80,7 кВт*ч
# 250 кВт
# BMW i4 eDr
# 2023
# 80,7 кВт*ч
# 400 кВт
# BMW i
# 2023
# 79,1 кВт*ч
# 210 кВт
# BMW i5 79.05 kWh eDrive 35
# 24 -
# 79,1 кВт*ч
# 210 кВт
# BMW i5 79.05 kWh eDrive 35L
# 24 -
# 79,1 кВт*ч
# 210 кВт
# BMW i5 79.05 kWh eDrive 35L Exclusiv
# 24 -
# 79,1 кВт*ч
# 210 кВт
# BMW i5 79.05 kWh eDrive 35L Exclusive
# 24 -
# 81,2 кВт*ч
# 442 кВт
# BMW i5 81.2 kWh xD
# 24 -
# 81,2 кВт*ч
# 250 кВт
# BMW i5 81.2 kWh
# 23 -
# 81,2 кВт*ч
# 250 кВт
# BMW i5 81.2 kWh eDrive40
# 23 -
# 81,2 кВт*ч
# 250 кВт
# BMW i5 81.2 kWh eDrive40 M S
# 23 -
# 81,2 кВт*ч
# 442 кВт
# BMW i5 81.2 kWh xD
# 23 -
# 101,7 кВт*ч
# 400 кВт
# BMW i7 101.7 kWh i7
# 22 -
# 101,7 кВт*ч
# 400 кВт
# BMW i7 101.7 kWh i7 xDrive60 M Sp
# 22 -
# 101,7 кВт*ч
# 400 кВт
# BMW i7 101.7 kWh i7 xDrive60 M Sportp
# 22 -
# 101,7 кВт*ч
# 400 кВт
# BMW i7 101.7 kWh i7
# 22 -
# 105,7 кВт*ч
# 400 кВт
# BMW i7 xDrive60 Ex
# 22 -
# 105,7 кВт*ч
# 400 кВт
# BMW i7 xDrive60
# 22 -
# 76,6 кВт*ч
# 240 кВт
# BMW iX 76.6 kWh
# 23 -
# 111,5 кВт*ч
# 385 кВт
# BMW iX 111.5 kWh
# 23 -
# 76,6 кВт*ч
# 240 кВт
# BMW iX 76.6 kWh xDr
# 2023
# 111,5 кВт*ч
# 455 кВт
# BMW iX 111.5
# 22 -
# 111,5 кВт*ч
# 385 кВт
# BMW iX 111.5 kWh xDr
# 2023
# 111,5 кВт*ч
# 397 кВт
# BM
# 22 -
# 76,6 кВт*ч
# 240 кВт
# BMW iX
# 21 -
# 76,6 кВт*ч
# 240 кВт
# BMW iX xDrive40 Sport Pack
# 21 -
# 111,5 кВт*ч
# 385 кВт
# BMW iX
# 21 -
# 71,0 кВт*ч
# 240 кВт
# BMW iX xDrive40 Suite
# 2023
# 71,0 кВт*ч
# 240 кВт
# BMW iX xDrive40 Atelier
# 2023
# 71,0 кВт*ч
# 240 кВт
# BMW iX xDrive40 Loft
# 2023
# 71,0 кВт*ч
# 240 кВт
# BMW iX xDrive40 Suite
# 2023
# 105,2 кВт*ч
# 455 кВт
# BMW iX M60 Loft
# 2023
# 105,2 кВт*ч
# 455 кВт
# BMW iX M60 Suite
# 2023
# 105,2 кВт*ч
# 385 кВт
# BMW iX xDrive50 Atelier
# 2023
# 105,2 кВт*ч
# 385 кВт
# BMW iX xDrive50 Loft
# 2022
# 105,2 кВт*ч
# 385 кВт
# BMW iX xDrive50 Loft
# 2023
# 105,2 кВт*ч
# 385 кВт
# BMW iX xDrive50 Suite
# 2023
# 105,2 кВт*ч
# 385 кВт
# BMW iX xDrive50 Suite
# 2023
# 0       95,0 кВт*ч
# 1       71,0 кВт*ч
# 2       71,0 кВт*ч
# 3       71,0 кВт*ч
# 4       95,0 кВт*ч
#           ...
# 127    105,2 кВт*ч
# 128    105,2 кВт*ч
# 129    105,2 кВт*ч
# 130    105,2 кВт*ч
# 131    105,2 кВт*ч
# Length: 132, dtype: object
# 0      300 кВт
# 1      230 кВт
# 2      230 кВт
# 3      230 кВт
# 4      300 кВт
#         ...
# 127    385 кВт
# 128    385 кВт
# 129    385 кВт
# 130    385 кВт
# 131    385 кВт
# Length: 132, dtype: object
# 0           Audi e-tron e-tron 55 quattr
# 1               Audi e-tron e-tron 50 qu
# 2      Audi e-tron e-tron 50 quattro adv
# 3           Audi e-tron e-tron 50 quattr
# 4        Audi e-tron 95 kWh 55 quattro e
#                      ...
# 127              BMW iX xDrive50 Atelier
# 128                 BMW iX xDrive50 Loft
# 129                BMW iX xDrive50 Loft
# 130                BMW iX xDrive50 Suite
# 131               BMW iX xDrive50 Suite
# Length: 132, dtype: object
# 0      21 -
# 1      2022
# 2      2021
# 3      20 -
# 4      2022
#        ...
# 127    2023
# 128    2022
# 129    2023
# 130    2023
# 131    2023
# Length: 132, dtype: object

# %%
pd4 = pd.Series(list_errors)
print(pd4)
# Out:
# Series([], dtype: float64)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\229082404.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd4 = pd.Series(list_errors)

# %%
num_url = url[-1:]
excel_name = num_url + ".xlsx"

# создаем таблицу с текущим номером страницы
pd.concat([pd3, pd5, pd1, pd2], axis=1).to_excel(excel_name)
new_out = pd.read_excel(excel_name, index_col=0)


# читаем пред таблицу
num_url2 = int(num_url) - 1
excel_name2 = str(num_url2) + ".xlsx"

old_out = pd.read_excel(excel_name2, index_col=0)



# сохраняем новый файл объекдиненный
outs = [old_out, new_out]

pd.concat(outs).to_excel(excel_name)
print(excel_name)
# Out:
# 4.xlsx

# %%
out89 = pd.read_excel('out89.xlsx', index_col=0)
out89
# Out:
#                                                      0           1        2
# 0    Chery Arrizo 5e 54.3 kWh Travel (12.2018 - н.в...  54,3 кВт*ч  120 кВт
# 1    Chery Arrizo 5e 54.3 kWh Comfort (12.2018 - 10...  54,3 кВт*ч  120 кВт
# 2    Chery Arrizo 5e 54.3 kWh Exclusive (12.2018 - ...  54,3 кВт*ч  120 кВт
# 3    Chery QQ Sweet 22.3 kWh Comfort (11.2014 - 12....  22,3 кВт*ч   42 кВт
# 4    Chery QQ Sweet 22.3 kWh Shared (11.2014 - 12.2...  22,3 кВт*ч   42 кВт
# ..                                                 ...         ...      ...
# 157  GAC Aion V 80 kWh Changxiang Healthy Edition (...  80,0 кВт*ч  135 кВт
# 158  GAC Aion V 80 kWh Smart Technology Edition (06...  80,0 кВт*ч  135 кВт
# 159  GAC Aion V 80 kWh Enjoy Smart Driving Edition ...  80,0 кВт*ч  135 кВт
# 160  GAC Aion V 80 kWh Driving Enjoy Zhizun Edition...  80,0 кВт*ч  135 кВт
# 161  GAC Aion V 80 kWh MAX Edition (06.2020 - 09.20...  80,0 кВт*ч  135 кВт
#
# [1282 rows x 3 columns]

# %%
out10 = pd.read_excel('out10.xlsx', index_col=0)

# %%
outs = [out89, out10]

# %%
result = pd.concat(outs).to_excel('out910.xlsx')
